# %%
MODEL_FLAGS="--attention_resolutions 32,16,8 --class_cond False --dropout 0.1 --diffusion_steps 1000 --image_size 128 --learn_sigma True --noise_schedule cosine --num_channels 128 --num_heads 4 --num_res_blocks 2 --resblock_updown True --use_fp16 False --use_scale_shift_norm True"
MODEL_PATH="--model_path /poc-data/pvn/model/diffusion/seismic-diffusion-v2/model100000.pt --swin_model_path /poc-data/pvn/model/swin-transformer/SCRN/trained_model/diffusion_settings/model_080.pth"
MODEL_PATH2="--model_path /poc-data/pvn/model/diffusion/GenerativeDiffusionPrior/results/ckpt/model300000.pt --swin_model_path /poc-data/pvn/model/swin-transformer/SCRN/trained_model/diffusion_settings/model_080.pth"

SAMPLE_FLAGS="--mask_ratio 0.4 --noise_scale 0.01 --gradient_scale 1"
# !python3 sample.py $MODEL_FLAGS $MODEL_PATH $SAMPLE_FLAGS --cuda_devices '0' --batch_size 16 --start_idx 0 --end_idx 1 --mode test --method gdp --data_dir '/poc-data/pvn/data' --dataset 'F3,Kerry3D'
# Out:
# Evaluation on dataset(s):  F3,Kerry3D
# (255, 601, 200)
# (1252, 144, 295)
# Number data: 14624
# /home/vhtdemo/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 100%|███████████████████████████████████████| 1000/1000 [01:25<00:00, 11.64it/s]
# [Diffusion] 0: SSIM: 0.8343864579927277 - PSNR: 25.530708760494015 - SNR: 19.682070016860962
# [Swin] 0: SSIM: 0.8914105709439493 - PSNR: 27.60872837153999 - SNR: 21.77299976348877
# [Diffusion] 1: SSIM: 0.8624659104282446 - PSNR: 25.127695714377936 - SNR: 19.322922229766846
# [Swin] 1: SSIM: 0.9147364002579712 - PSNR: 27.76060172902172 - SNR: 21.970679759979248
# [Diffusion] 2: SSIM: 0.8138881437309388 - PSNR: 24.41941893582746 - SNR: 18.56068730354309
# [Swin] 2: SSIM: 0.8757294815208059 - PSNR: 26.533703017376773 - SNR: 20.679917335510254
# [Diffusion] 3: SSIM: 0.8584893222712145 - PSNR: 26.917979394331436 - SNR: 21.170763969421387
# [Swin] 3: SSIM: 0.8970993957230984 - PSNR: 29.361678957280773 - SNR: 23.635551929473877
# [Diffusion] 4: SSIM: 0.8516174812038377 - PSNR: 26.232941990884996 - SNR: 20.37581205368042
# [Swin] 4: SSIM: 0.8975680346283036 - PSNR: 28.12449152464746 - SNR: 22.27464199066162
# [Diffusion] 5: SSIM: 0.8783184134807711 - PSNR: 26.11086317328506 - SNR: 20.288634300231934
# [Swin] 5: SSIM: 0.9206516850795328 - PSNR: 28.332455024917763 - SNR: 22.528071403503418
# [Diffusion] 6: SSIM: 0.8372239499972768 - PSNR: 25.156826896648106 - SNR: 19.28621768951416
# [Swin] 6: SSIM: 0.8902449916155822 - PSNR: 26.91243150891823 - SNR: 21.062376499176025
# [Diffusion] 7: SSIM: 0.8735912385813082 - PSNR: 28.04245845256 - SNR: 22.295947074890137
# [Swin] 7: SSIM: 0.9118531503303574 - PSNR: 29.76356656716437 - SNR: 24.038238525390625
# [Diffusion] 8: SSIM: 0.9500730150127861 - PSNR: 32.2717302488272 - SNR: 26.3616943359375
# [Swin] 8: SSIM: 0.9812104416138582 - PSNR: 36.716179560462045 - SNR: 30.822665691375732
# [Diffusion] 9: SSIM: 0.9519145920344352 - PSNR: 30.697326362678616 - SNR: 24.834415912628174
# [Swin] 9: SSIM: 0.9835359643736323 - PSNR: 35.70892890688518 - SNR: 29.857141971588135
# [Diffusion] 10: SSIM: 0.9397392156945542 - PSNR: 31.262567269918215 - SNR: 25.369138717651367
# [Swin] 10: SSIM: 0.97775990771257 - PSNR: 35.124547887303585 - SNR: 29.240541458129883
# [Diffusion] 11: SSIM: 0.956902893494638 - PSNR: 34.105723474889366 - SNR: 28.337373733520508
# [Swin] 11: SSIM: 0.9817260005693789 - PSNR: 37.11924565632537 - SNR: 31.36855125427246
# [Diffusion] 12: SSIM: 0.9565756335503378 - PSNR: 32.96584850513574 - SNR: 27.055203914642334
# [Swin] 12: SSIM: 0.9836114544671434 - PSNR: 37.08006985389947 - SNR: 31.187889575958252
# [Diffusion] 13: SSIM: 0.9564793404579459 - PSNR: 31.081434069846935 - SNR: 25.22334098815918
# [Swin] 13: SSIM: 0.9866285984893326 - PSNR: 36.57503785925087 - SNR: 30.72922706604004
# [Diffusion] 14: SSIM: 0.9511471761625162 - PSNR: 31.42425311163709 - SNR: 25.54683208465576
# [Swin] 14: SSIM: 0.977421544012035 - PSNR: 34.249042860765 - SNR: 28.38461399078369
# [Diffusion] 15: SSIM: 0.9648262182049405 - PSNR: 33.12992834637265 - SNR: 27.380950450897217
# [Swin] 15: SSIM: 0.9843801637418232 - PSNR: 37.36791385736832 - SNR: 31.634647846221924

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('samples/sample10.npz')

# %%
plt.figure(figsize=(16,64))
plt.subplot(1,4,1)
plt.imshow(data['original'], plt.cm.seismic)
plt.subplot(1,4,2)
plt.imshow(data['masked_image'], plt.cm.seismic)
plt.subplot(1,4,3)
plt.imshow(data['diffusion_sample'], plt.cm.seismic)
plt.subplot(1,4,4)
plt.imshow(data['swin_sample'], plt.cm.seismic)

# %%
import torch

# %%
from swin import SCRN, ConvTransBlock, Block, WMSA

# %%
swin_model = torch.load('/poc-data/pvn/model/swin-transformer/SCRN/trained_model/diffusion_settings/model_080.pth')
swin_model.to(torch.device('cuda:0'))
swin_model.eval()
# Out:
# SCRN(
#   (m_head): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (m1): Sequential(
#     (0): ConvTransBlock(
#       (trans_block): Block(
#         (ln1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (msa): WMSA(
#           (embedding_layer): Linear(in_features=32, out_features=96, bias=True)
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (drop_path): Identity()
#         (ln2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=32, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=32, bias=True)
#         )
#       )
#       (conv1_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv1_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv_block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#       )
#     )
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (m2): Sequential(
#     (0): ConvTransBlock(
#       (trans_block): Block(
#         (ln1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (msa): WMSA(
#           (embedding_layer): Linear(in_features=32, out_features=96, bias=True)
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (drop_path): Identity()
#         (ln2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=32, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=32, bias=True)
#         )
#       )
#       (conv1_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv1_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv_block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#       )
#     )
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (m3): Sequential(
#     (0): ConvTransBlock(
#       (trans_block): Block(
#         (ln1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (msa): WMSA(
#           (embedding_layer): Linear(in_features=32, out_features=96, bias=True)
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (drop_path): Identity()
#         (ln2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=32, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=32, bias=True)
#         )
#       )
#       (conv1_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv1_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv_block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#       )
#     )
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (m4): Sequential(
#     (0): ConvTransBlock(
#       (trans_block): Block(
#         (ln1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (msa): WMSA(
#           (embedding_layer): Linear(in_features=32, out_features=96, bias=True)
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (drop_path): Identity()
#         (ln2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=32, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=32, bias=True)
#         )
#       )
#       (conv1_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv1_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv_block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#       )
#     )
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (m5): Sequential(
#     (0): ConvTransBlock(
#       (trans_block): Block(
#         (ln1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (msa): WMSA(
#           (embedding_layer): Linear(in_features=32, out_features=96, bias=True)
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (drop_path): Identity()
#         (ln2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=32, out_features=128, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=128, out_features=32, bias=True)
#         )
#       )
#       (conv1_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv1_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv_block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#       )
#     )
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (m_tail): Sequential(
#     (0): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
# )

# %%
data = np.load('samples/sample0.npz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = np.load('samples/sample0.npz')
#
# NameError: name 'np' is not defined

# %%
def normalize(image):
    """Basic min max scaler.
    """
    min_ = np.min(image)
    max_ = np.max(image)
    scale = max_ - min_
    image = (image - min_) / scale
    image = image * 2 - 1
    return image

# %%
out = swin_model(torch.tensor(normalize(data['masked_image'])).permute(2,0,1).unsqueeze(0).to(torch.float32).to(torch.device('cuda:0')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 out = swin_model(torch.tensor(normalize(data['masked_image'])).permute(2,0,1).unsqueeze(0).to(torch.float32).to(torch.device('cuda:0')))
#
# NameError: name 'swin_model' is not defined

# %%
data['masked_image'].shape
# Out:
# (128, 128, 1)

# %%
plt.imshow(out.cpu().detach().numpy()[0][0], plt.cm.seismic)

# %%
import scipy

# %%
plt.imshow(data['masked_image'], plt.cm.seismic)

# %%
s = scipy.ndimage.gaussian_filter(data['masked_image'][:, :, 0], 1)
plt.imshow(s, plt.cm.seismic)

# %%
s = scipy.signal.median_filt(data['masked_image'][:, :, 0], 0.25)
plt.imshow(s, plt.cm.seismic)

# %%
from wavelet_util import DWT_2D
dwt = DWT_2D('haar')

# %%
xLL, xLH, xHL, xHH = dwt(torch.tensor(normalize(data['masked_image'])).permute(2,0,1).unsqueeze(0).to(torch.float32).to(torch.device('cuda:0')))

x = torch.cat((xLL, xLH, xHL, xHH), dim=1) / 2.0

# %%
plt.imshow(x.cpu()[0][0], plt.cm.seismic)

# %%
from piq import SSIMLoss

# %%
ssimloss = SSIMLoss(x, data_range=-2.0 )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[464], line 1
# ----> 1 ssimloss = SSIMLoss(x, data_range=-2.0 )
#
# File /usr/local/lib/python3.8/dist-packages/piq/ssim.py:148, in SSIMLoss.__init__(self, kernel_size, kernel_sigma, k1, k2, downsample, reduction, data_range)
#     144 self.kernel_size = kernel_size
#     146 # This check might look redundant because kernel size is checked within the ssim function anyway.
#     147 # However, this check allows to fail fast when the loss is being initialised and training has not been started.
# --> 148 assert kernel_size % 2 == 1, f'Kernel size must be odd, got [{kernel_size}]'
#     149 self.kernel_sigma = kernel_sigma
#     150 self.k1 = k1
#
# RuntimeError: Boolean value of Tensor with more than one value is ambiguous

# %%
ssimloss(x,x+0.2)
# Out:
# tensor(0.8429, device='cuda:0')

# %%
from ssim_util import SSIM

# %%
ssim_loss = SSIM(11, size_average=True)

# %%
ssim_loss(x, x+0.2)
# Out:
# tensor([[-0.0343, -0.0163, -0.0024,  0.0054]], device='cuda:0')
